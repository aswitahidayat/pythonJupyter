# %%
import matplotlib.pyplot as plt
import datetime
import numpy as np
import matplotlib.path as mpath
import matplotlib.lines as mlines

# %%
x = [4,8,13,17,20]
plt.plot(x,[54, 67, 98, 78, 45], label="Data 1")
plt.plot(x,[70, 90, 50, 78, 39] , label="Data 2")
plt.legend()
# plt.plot([10,8,8,10,12,12,10,10,8.3, 8.3, 10, 11.5, 11.5, 10],
#          [30, 67, 90, 78, 90, 67,30, 40,72, 82, 70, 80, 63, 40])

plt.show()

# %%
x = [2,4,6,5,42,543,5,3,73,64,42,97,63,76,63,8,73,97,23,45,56,89,
45,3,23,2,5,78,23,56,67,78,8,3,78,34,67,23,324,234,43,544,54,33,223,443,444,234,76,432,233,23,232,243,222,221,254,222,276,300,353,354,387,364,309]
num_bins = 9
n, bins, patches = plt.hist(x, num_bins, facecolor = 'green')
plt.show()

# %%
x = np.array([datetime.datetime(2019, 9, 20 + i, 0) for i in range(6)])
y = np.random.randint(1000, size=x.shape)
plt.plot(x,y)
plt.show()

print(x)
# Out:
# [datetime.datetime(2019, 9, 20, 0, 0) datetime.datetime(2019, 9, 21, 0, 0)
#  datetime.datetime(2019, 9, 22, 0, 0) datetime.datetime(2019, 9, 23, 0, 0)
#  datetime.datetime(2019, 9, 24, 0, 0) datetime.datetime(2019, 9, 25, 0, 0)]

# %%
N = 20
theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
radii = 10 * np.random.rand(N)
width = np.pi / 4 * np.random.rand(N)

ax = plt.subplot(111, projection='polar')
bars = ax.bar(theta, radii, width=width, bottom=0.0)

# Use custom colors and opacity
for r, bar in zip(radii, bars):
    bar.set_facecolor(plt.cm.viridis(r / 10.))
    bar.set_alpha(0.5)

plt.show()
